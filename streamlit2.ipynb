# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedEsammohmaed/IBS/blob/main/streamlit2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok

# Set your ngrok authtoken
ngrok.set_auth_token("3IkN0dPTTQMNnyD4Vs8UQShBkSe_6iVZoCAu2nucMDqeZCLHP")

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 106.5 MB/s eta 0:00:00
# ...

# %%
import subprocess
import time
from pyngrok import ngrok

# 1. Kill all running processes on port 8501
# !pkill -f streamlit
ngrok.kill()

# 2. Launch Streamlit in the background
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501"])

# 3. Wait 3 seconds for Streamlit server initialization
time.sleep(3)

# 4. Open ngrok tunnel
public_url = ngrok.connect(8501)
print(f"🚀 Streamlit application is live at:\n{public_url}")
# Out:
# 🚀 Streamlit application is live at:
# NgrokTunnel: "https://relocate-negligent-casing.ngrok-free.dev" -> "http://localhost:8501"
